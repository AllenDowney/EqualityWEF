# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from utils import decorate, configure_plot_style, AIBM_COLORS

configure_plot_style()

# %%
from extract_pdf_data import extract_pdf_data

def read_pdfs():
    results = []
    for i in range(83, 375, 2):
        filename = f"pages/page_{i:03d}.pdf"
        print(f"Processing {filename}...")
        data = extract_pdf_data(i, filename)
        results.append(data)
    
    df = pd.DataFrame(results)
    return df

# %%
import os
if not os.path.exists("wef_tertiary_enrolment.csv"):
    df = read_pdfs()
    df.to_csv("wef_tertiary_enrolment.csv", index=False)

# %%
df = pd.read_csv("wef_tertiary_enrolment.csv")
df.shape
# Out:
# (146, 7)

# %%
df.head()
# Out:
#   country_name  page_number  tert_ed_score  tert_ed_rank  tert_ed_diff  \
# 0      Albania           83          1.000           1.0         24.48
# 1      Algeria           85          1.000           1.0         28.61
# 2       Angola           87          0.899         112.0         -1.17
# 3    Argentina           89          1.000           1.0         64.82
# 4      Armenia           91          1.000           1.0         16.72
#
#    tert_ed_left  tert_ed_right
# 0         50.60          75.08
# 1         39.40          68.01
# 2         10.48          11.65
# 3         75.48         140.30
# 4         51.61          68.34

# %%
df.tail()
# Out:
#     country_name  page_number  tert_ed_score  tert_ed_rank  tert_ed_diff  \
# 141   Uzbekistan          365          0.940         110.0         -2.54
# 142      Vanuatu          367            NaN           NaN           NaN
# 143     Viet Nam          369          1.000           1.0          2.65
# 144       Zambia          371            NaN           NaN           NaN
# 145     Zimbabwe          373          0.962         108.0         -0.38
#
#      tert_ed_left  tert_ed_right
# 141         39.87          42.41
# 142           NaN            NaN
# 143         40.93          43.58
# 144           NaN            NaN
# 145          9.54           9.92

# %% [markdown]
# The study includes 146 countries. We have tertiary education data for 135 of them (missing 11).
#
# In 104/135 countries, women participate in tertiary education at rates equal or higher than men, so there is a 104-way tie for Rank #1.
#
# So in 104 countries, the problem of gender equality in higher education is entirely solved, and there is no reason to allocate any further attention or resources to the problem. Yay!

# %%
df['tert_ed_rank'].value_counts(dropna=False)
# Out:
# tert_ed_rank
# 1.0      104
# NaN       11
# 112.0      1
# 117.0      1
# 131.0      1
# 127.0      1
# 124.0      1
# 113.0      1
# 114.0      1
# 135.0      1
# 120.0      1
# 129.0      1
# 119.0      1
# 128.0      1
# 109.0      1
# 134.0      1
# 105.0      1
# 107.0      1
# 121.0      1
# 132.0      1
# 116.0      1
# 133.0      1
# 126.0      1
# 111.0      1
# 123.0      1
# 106.0      1
# 115.0      1
# 125.0      1
# 130.0      1
# 122.0      1
# 118.0      1
# 110.0      1
# 108.0      1
# Name: count, dtype: int64

# %% [markdown]
# Only 31 countries received less than a perfect score in this category.

# %%
dinged = df['tert_ed_score'] < 1
dinged.sum()
# Out:
# np.int64(31)

# %% [markdown]
# Here is the distribution of their scores.

# %%
from empiricaldist import Cdf

cdf_score = Cdf.from_seq(df.loc[dinged, 'tert_ed_score'])
cdf_score.plot()
decorate(xlabel='Tertiary Enrolment Score', ylabel='CDF')

# %% [markdown]
# Here is the distribution of differences (female minus male in percentage points) for all countries with valid data.

# %%
cdf_difference_fm = Cdf.from_seq(df['tert_ed_diff'])
cdf_difference_fm.plot()
decorate(xlabel='Tertiary Enrolment Difference FM', ylabel='CDF')

# %% [markdown]
# In countries where women are lagging, they lag by fewer than 10 percentage points in most cases. In countries where men are lagging, the differences are much bigger, sometimes 40-60 percentage points.
# So the WEF metrics are hiding the biggest differences.
#
# Here are the countries where women lag men.

# %%
subset = df[dinged]
subset.sort_values("tert_ed_diff", ascending=False)
# Out:
#                         country_name  page_number  tert_ed_score  \
# 145                         Zimbabwe          373          0.962
# 114                          Senegal          311          0.973
# 61                             India          205          0.982
# 103                         Pakistan          289          0.926
# 138      United Republic of Tanzania          359          0.816
# 92                        Mozambique          267          0.853
# 2                             Angola           87          0.899
# 134                           Uganda          351          0.777
# 53                             Ghana          189          0.941
# 23                           Burundi          129          0.768
# 112                           Rwanda          307          0.771
# 25                          Cameroon          133          0.880
# 24                          Cambodia          131          0.882
# 68                             Japan          219          0.969
# 35                     Côte D'Ivoire          153          0.806
# 32                           Comoros          147          0.801
# 141                       Uzbekistan          365          0.940
# 98                             Niger          279          0.481
# 84                              Mali          251          0.508
# 33   Congo, Democratic Republic of t          149          0.593
# 99                           Nigeria          281          0.726
# 28                              Chad          139          0.394
# 9                         Bangladesh          101          0.841
# 22                      Burkina Faso          127          0.624
# 56                            Guinea          195          0.460
# 71                             Kenya          225          0.781
# 46                          Ethiopia          175          0.598
# 14                             Benin          111          0.563
# 131                             Togo          345          0.570
# 128                       Tajikistan          339          0.727
# 121                      South Korea          325          0.861
#
#      tert_ed_rank  tert_ed_diff  tert_ed_left  tert_ed_right
# 145         108.0         -0.38          9.54           9.92
# 114         106.0         -0.46         16.57          17.04
# 61          105.0         -0.59         32.81          33.40
# 103         111.0         -1.03         12.90          13.93
# 138         118.0         -1.10          4.88           5.98
# 92          116.0         -1.16          6.72           7.88
# 2           112.0         -1.17         10.48          11.65
# 134         122.0         -1.20          4.16           5.36
# 53          109.0         -1.24         19.77          21.00
# 23          124.0         -1.71          5.66           7.37
# 112         123.0         -1.82          6.12           7.94
# 25          114.0         -1.83         13.39          15.22
# 24          113.0         -1.89         14.06          15.95
# 68          107.0         -2.01         62.14          64.15
# 35          119.0         -2.10          8.72          10.82
# 32          120.0         -2.12          8.56          10.68
# 141         110.0         -2.54         39.87          42.41
# 98          133.0         -2.98          2.76           5.73
# 84          132.0         -3.08          3.17           6.25
# 33          129.0         -3.41          4.97           8.37
# 99          126.0         -3.75          9.91          13.65
# 28          135.0         -3.93          2.55           6.48
# 9           117.0         -3.94         20.84          24.78
# 22          127.0         -4.49          7.46          11.95
# 56          134.0         -4.94          4.21           9.16
# 71          121.0         -5.05         17.99          23.04
# 46          128.0         -5.21          7.74          12.96
# 14          131.0         -5.70          7.34          13.04
# 131         130.0         -8.22         10.91          19.13
# 128         125.0         -9.84         26.19          36.03
# 121         115.0        -15.43         95.23         110.66

# %% [markdown]
# The data for South Korea are weird. Male enrollment is 111% and for women it's "only" 95%.
# Maybe the denominator is college-age people and "college age" is shifted because of mandatory military service?

# %% [markdown]
# The scores are based on ratios, not differences, so let's compute those.

# %%
df['ratio'] = df['tert_ed_left'] / df['tert_ed_right']
df['ratio'].describe()
# Out:
# count    135.000000
# mean       0.741685
# std        0.147372
# min        0.212956
# 25%        0.658574
# 50%        0.746673
# 75%        0.850590
# max        0.999506
# Name: ratio, dtype: float64

# %% [markdown]
# Looks like the ratio IS the score.

# %%
subset = df[dinged]
plt.plot([0, 1], [0, 1], color='gray', alpha=0.4)
plt.scatter(subset['ratio'], subset['tert_ed_score'])
decorate(xlabel='Ratio', ylabel='Score')

# %%
from scipy.stats import linregress

slope, intercept, r_value, p_value, std_err = linregress(
    subset['ratio'], subset['tert_ed_score'])

print(f"Slope: {slope}")
print(f"Intercept: {intercept}")
print(f"R-value: {r_value}")
print(f"P-value: {p_value}")
print(f"Standard Error: {std_err}")
# Out:
# Slope: 0.9998860394149466
# Intercept: 0.00016965563677673323
# R-value: 0.9999968288921758
# P-value: 6.302077788732111e-77
# Standard Error: 0.00046759842654030753

# %% [markdown]
# So here are the revised, symmetric scores.

# %%
df['revised_score'] = df['ratio']
df['revised_score'].describe()
# Out:
# count    135.000000
# mean       0.741685
# std        0.147372
# min        0.212956
# 25%        0.658574
# 50%        0.746673
# 75%        0.850590
# max        0.999506
# Name: revised_score, dtype: float64

# %% [markdown]
# Here's the distribution of revised scores.

# %%
cdf_score = Cdf.from_seq(df['revised_score'])
cdf_score.plot()
decorate(xlabel='Revised Enrolment Score', ylabel='CDF')

# %%
revised = df[~dinged].dropna(subset=['ratio']).sort_values('revised_score')
revised.shape
# Out:
# (104, 9)

# %%
# make a figure that shows a horizontal line for each country that
# connects the revised score and the tertiary enrolment score
# with a circle for the original and a triangle for the revised

from utils import add_title, add_subtext, add_logo

fig, ax = plt.subplots(figsize=(6, 15))
plt.hlines(revised['country_name'], 
           revised['tert_ed_score'], revised['revised_score'], 
           color=AIBM_COLORS['light_gray'])
plt.plot(revised['tert_ed_score'], revised['country_name'], '|', 
         color=AIBM_COLORS['blue'])
plt.plot(revised['revised_score'], revised['country_name'], '<', 
         color=AIBM_COLORS['blue'])
ax.invert_yaxis()

decorate(xlabel='Tertiary Enrolment Score', ylim=[len(revised)+1, -1])
add_title("Revised Scores Are Very Different For Many Countries",
          "Subtitle", y=1.01)
add_subtext("Source: World Economic Forum", y=-0.05)
logo = add_logo(location=(1.0, -0.05))

# %% [markdown]
# And here's the new ranking of countries based on revised scores.

# %%
columns = ['revised_rank', 'country_name', 'tert_ed_score', 'revised_score', 'tert_ed_diff']
df_sorted = df.dropna(subset=['ratio']).sort_values(by='revised_score', ascending=False)
df_sorted['revised_rank'] = np.arange(1, len(df_sorted)+1)
table = df_sorted[columns].round(2)
table.to_csv("wef_tertiary_enrolment_table.csv", index=False)

# %%
df_sorted[columns].head(40).round(2)

# %%
df_sorted[columns].tail(50).round(2)
# Out:
#      revised_rank                     country_name  tert_ed_score  \
# 36             86                          Croatia           1.00
# 115            87                           Serbia           1.00
# 19             88                           Brazil           1.00
# 139            89         United States of America           1.00
# 102            90                             Oman           1.00
# 27             91                       Cape Verde           1.00
# 85             92                            Malta           1.00
# 0              93                          Albania           1.00
# 8              94                          Bahrain           1.00
# 100            95                  North Macedonia           1.00
# 79             96                        Lithuania           1.00
# 118            97                         Slovakia           1.00
# 5              98                        Australia           1.00
# 101            99                           Norway           1.00
# 20            100                Brunei Darussalam           1.00
# 119           101                         Slovenia           1.00
# 77            102                          Lesotho           1.00
# 44            103                          Estonia           1.00
# 108           104                           Poland           1.00
# 18            105                         Botswana           1.00
# 72            106                           Kuwait           1.00
# 104           107                           Panama           1.00
# 17            108           Bosnia and Herzegovina           1.00
# 22            109                     Burkina Faso           0.62
# 120           110                     South Africa           1.00
# 96            111                      New Zealand           1.00
# 89            112                         Mongolia           1.00
# 123           113                        Sri Lanka           1.00
# 46            114                         Ethiopia           0.60
# 33            115  Congo, Democratic Republic of t           0.59
# 132           116                          Tunisia           1.00
# 1             117                          Algeria           1.00
# 67            118                          Jamaica           1.00
# 126           119                           Sweden           1.00
# 131           120                             Togo           0.57
# 14            121                            Benin           0.56
# 140           122                          Uruguay           1.00
# 13            123                           Belize           1.00
# 3             124                        Argentina           1.00
# 93            125                          Namibia           1.00
# 125           126                         Suriname           1.00
# 84            127                             Mali           0.51
# 60            128                          Iceland           1.00
# 98            129                            Niger           0.48
# 40            130               Dominican Republic           1.00
# 56            131                           Guinea           0.46
# 83            132                         Maldives           1.00
# 136           133             United Arab Emirates           1.00
# 28            134                             Chad           0.39
# 110           135                            Qatar           1.00
#
#      revised_score  tert_ed_diff
# 36            0.69         26.82
# 115           0.68         24.92
# 19            0.68         22.78
# 139           0.68         30.31
# 102           0.68         17.03
# 27            0.68          7.82
# 85            0.68         30.66
# 0             0.67         24.48
# 8             0.67         30.31
# 100           0.67         16.40
# 79            0.67         28.38
# 118           0.67         21.00
# 5             0.67         42.64
# 101           0.66         38.33
# 20            0.66         13.36
# 119           0.66         34.14
# 77            0.66          4.03
# 44            0.65         29.95
# 108           0.65         32.05
# 18            0.64         10.11
# 72            0.64         27.60
# 104           0.63         24.29
# 17            0.63         20.57
# 22            0.62         -4.49
# 120           0.61         12.21
# 96            0.61         38.54
# 89            0.61         32.06
# 123           0.60         11.42
# 46            0.60         -5.21
# 33            0.59         -3.41
# 132           0.58         20.15
# 1             0.58         28.61
# 67            0.58         14.23
# 126           0.58         46.02
# 131           0.57         -8.22
# 14            0.56         -5.70
# 140           0.56         42.89
# 13            0.55         13.88
# 3             0.54         64.82
# 93            0.53         17.34
# 125           0.51          5.77
# 84            0.51         -3.08
# 60            0.49         59.26
# 98            0.48         -2.98
# 40            0.48         41.17
# 56            0.46         -4.94
# 83            0.42         30.90
# 136           0.40         58.13
# 28            0.39         -3.93
# 110           0.21         60.87

# %%
df.query("country_name == 'Qatar'")
# Out:
#     country_name  page_number  tert_ed_score  tert_ed_rank  tert_ed_diff  \
# 110        Qatar          303            1.0           1.0         60.87
#
#      tert_ed_left  tert_ed_right     ratio  revised_score
# 110         16.47          77.34  0.212956       0.212956

# %%
import seaborn as sns

options = dict(cut=0, bw_adjust=0.7)

sns.kdeplot(df['tert_ed_score'], label='WEF truncated scores', **options)
sns.kdeplot(df['revised_score'], label='Revised symmetric scores', **options)

plt.xlabel('Gender equality score')
plt.title('Enrollment in tertiary education')
plt.legend()
None
